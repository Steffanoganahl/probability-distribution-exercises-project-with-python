# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO

from scipy.stats import norm, uniform

# Definir todas las funciones de probabilidad relacionadas con la distribución normal.

def dnorm(x, mean = 0, sd = 1):
    """
    Calcula la estimación puntual de la función de densidad de probabilidad (PDF) de la distribución normal.
    """
    result = norm.pdf(x = x, loc = mean, scale = sd)
    return result

def pnorm(q, mean = 0, sd = 1):
    """
    Calcula el acumulado de la función de distribución acumulada (CDF) de la distribución normal.
    """
    result = norm.cdf(x = q, loc = mean, scale = sd)
    return result

def qnorm(p, mean = 0, sd = 1):
    """
    Calcula la función cuantil (inversa de la CDF) a partir de la distribución normal.
    """
    result = norm.ppf(q = p, loc = mean, scale = sd)
    return result

def rnorm(n, mean = 0, sd = 1):
    """
    Genera variables aleatorias a partir de la distribución normal.
    """
    result = norm.rvs(loc = mean, scale = sd, size = n)
    return result


# Definir todas las funciones de probabilidad relacionadas con la distribución uniforme.

def dunif(x, min = 0, max = 1):
    """
    Calcula la estimación puntual de la función de densidad de probabilidad (PDF) de la distribución uniforme.
    """
    result = uniform.pdf(x = x, loc = min, scale = max - min)
    return result

def punif(q, min = 0, max = 1):
    """
    Calcula el acumulado de la función de distribución acumulada (CDF) de la distribución uniforme.
    """
    result = uniform.cdf(x = q, loc = min, scale = max - min)
    return result

def qunif(p, min = 0, max = 1):
    """
    Calcula la función cuantil (inversa de la CDF) a partir de la distribución uniforme.
    """
    result = uniform.ppf(q = p, loc = min, scale = max - min)
    return result

def runif(n, min = 0, max = 1):
    """
    Genera variables aleatorias a partir de la distribución uniforme.
    """
    result = uniform.rvs(loc = min, scale = max - min, size = n)
    return result

    # Para las distribuciones Normal y Uniforme, se han recreado un conjunto de funciones análogas a las previamente definidas
    # para la distribución Binomial (dbinom, pbinom, qbinom, rbinom). Estas funciones se basan en la librería scipy.stats de Python,
    # que proporciona implementaciones eficientes y precisas para una amplia gama de distribuciones de probabilidad.
    
    # A continuación se generaran vistas gráficas de las funciones anteriores pero con las nuevas normal y uniforme. 


np.random.seed(42)

# Parameters for Normal Distribution / Parametros para Distribucion Normal 
mean = 0
sd = 1
n_samples = 2000

# Generate random samples / muestreo aleatorio 
data_norm_rvs = rnorm(n_samples, mean=mean, sd=sd)

# Create a sorted range of x-values for plotting PDF curve / Valores para graficar x
x_values_norm = np.linspace(min(data_norm_rvs) - 0.5, max(data_norm_rvs) + 0.5, 500)

# Calculate PDF / Calcular PDF
pdf_norm = dnorm(x_values_norm, mean=mean, sd=sd)

# Plot for Normal Distribution / Grafica para DN
plt.figure(figsize=(8, 6))
plt.hist(data_norm_rvs, bins=30, density=True, alpha=0.6, color='skyblue', label='Histogram of Samples')
plt.plot(x_values_norm, pdf_norm, 'r-', linewidth=2, label='Theoretical PDF')
plt.title('Normal Distribution (mean=0, sd=1) - PDF and Samples')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

#-----------

np.random.seed(42)

# Parameters for Uniform Distribution / Parametros para Distribucion Uniforme 
min_val = 0
max_val = 1
n_samples = 2000

# Generate random samples / muestreo aleatorio 
data_unif_rvs = runif(n_samples, min=min_val, max=max_val)

# Create a sorted range of x-values for plotting PDF curve / Valores para graficar x
x_values_unif = np.linspace(min_val - 0.2, max_val + 0.2, 500)

# Calculate PDF / Calcular PDF
pdf_unif = dunif(x_values_unif, min=min_val, max=max_val)

# Plot for Uniform Distribution / Grafica para DN
plt.figure(figsize=(8, 6))
plt.hist(data_unif_rvs, bins=30, density=True, alpha=0.6, color='lightgreen', label='Histogram of Samples')
plt.plot(x_values_unif, pdf_unif, 'r-', linewidth=2, label='Theoretical PDF')
plt.title('Uniform Distribution (min=0, max=1) - PDF and Samples')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
